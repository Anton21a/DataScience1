# %%
import pandas as pd
df = pd.read_csv("clean_data.csv")
df
# Out:
#       happiness  financial_satisfaction  age  gender  religion
# 0             2                       8   76       2         2
# 1             2                       2   69       1         1
# 2             3                       8   35       2         0
# 3             2                       8   45       1         2
# 4             4                       9   32       1         2
# ...         ...                     ...  ...     ...       ...
# 4013          1                      10   50       1         3
# 4014          2                       5   38       1         4
# 4015          2                       7   70       1         2
# 4016          2                       8   64       2         2
# 4017          2                       8   37       1         0
#
# [4018 rows x 5 columns]

# %%
import statsmodels.formula.api as smf

df["happiness"] = df["happiness"].astype("int")
df["financial_satisfaction"] = df["financial_satisfaction"].astype("category")
df["religion"] = df["religion"].astype("category")
df["gender"] = df["gender"].astype("category")

model = smf.ols("happiness ~ financial_satisfaction + age + gender + religion", data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              happiness   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     57.01
# Date:                Fri, 03 Oct 2025   Prob (F-statistic):          2.84e-200
# Time:                        18:55:41   Log-Likelihood:                -3289.1
# No. Observations:                4018   AIC:                             6620.
# Df Residuals:                    3997   BIC:                             6753.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...
