# %% [markdown]
# Please find all necessary information about variable description in Markdown file

# %% [markdown]
# ### Uploading the dataset

# %%
import pandas as pd
df = pd.read_csv("raw_data.csv")
df
# Out:
#       Unnamed: 0  year  religion_importance  happiness  gender  age  religion  \
# 0              1  2020                    1          2       2   76         2
# 1              2  2020                    1          2       1   69         1
# 2              3  2020                    4          3       2   35         0
# 3              4  2020                    2          2       1   45         2
# 4              5  2020                    2          4       1   32         2
# ...          ...   ...                  ...        ...     ...  ...       ...
# 4013        4014  2020                    1          1       1   50         3
# 4014        4015  2020                    1          2       1   38         4
# 4015        4016  2020                    2          2       1   70         2
# 4016        4017  2020                    3          2       2   64         2
# 4017        4018  2020                    4          2       1   37         0
#
# ...

# %% [markdown]
# ### Basic Analysis

# %%
print(df.shape)

print(df.info())

print(df.head())
# Out:
# (4018, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4018 entries, 0 to 4017
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              4018 non-null   int64
#  1   year                    4018 non-null   int64
#  2   religion_importance     4018 non-null   int64
#  3   happiness               4018 non-null   int64
#  4   gender                  4018 non-null   int64
#  5   age                     4018 non-null   int64
#  6   religion                4018 non-null   int64
#  7   financial_satisfaction  4018 non-null   int64
#  8   living_standard         4018 non-null   int64
#  9   trust_people            4018 non-null   int64
#  10  trust_family            4018 non-null   int64
#  11  trust_foreigners        4018 non-null   int64
# dtypes: int64(12)
# memory usage: 376.8 KB
# None
#    Unnamed: 0  year  religion_importance  happiness  gender  age  religion  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# year                      0
# religion_importance       0
# happiness                 0
# gender                    0
# age                       0
# religion                  0
# financial_satisfaction    0
# living_standard           0
# trust_people              0
# trust_family              0
# trust_foreigners          0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0    year  religion_importance    happiness       gender  \
# count  4018.000000  4018.0          4018.000000  4018.000000  4018.000000
# mean   2009.500000  2020.0             2.875062     1.946242     1.487556
# std    1160.041019     0.0             1.082286     0.622055     0.499907
# min       1.000000  2020.0             1.000000     1.000000     1.000000
# 25%    1005.250000  2020.0             2.000000     2.000000     1.000000
# 50%    2009.500000  2020.0             3.000000     2.000000     1.000000
# 75%    3013.750000  2020.0             4.000000     2.000000     2.000000
# max    4018.000000  2020.0             4.000000     4.000000     2.000000
#
#                age     religion  financial_satisfaction  living_standard  \
# count  4018.000000  4018.000000             4018.000000      4018.000000
# mean     46.564709     1.370582                6.523644         1.773519
# std      16.877479     2.162044                2.219152         0.862158
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df['age'].hist(figsize=(13,5))
plt.show()

# %%
df[["financial_satisfaction","living_standard","happiness"]].boxplot()
plt.show()

# %% [markdown]
# ### Uploading clean dataset

# %%
clean_df = df[["happiness", "financial_satisfaction", "age", "gender", "religion"]]

clean_df.to_csv("clean_data.csv", index = False)
